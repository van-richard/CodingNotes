# %% [markdown]
# # Nav

# %%
# %%bash
#
# ls
# pwd
# Out:
# BasicMD.md
# CondaPython.md
# FileManagement.md
# Nav.ipynb
# Navigation.md
# Overview.md
# PDBFiles.md
# SSH.md
# Slurm.md
# StructureFiles.md
# Supercomputer.md
# Terminal.md
# XYZFiles.md
# /Users/van/Library/CloudStorage/Dropbox/github/CodingNotes/notebooks/QuickStart
